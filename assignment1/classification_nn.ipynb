# %% [markdown]
# # ECE 285 Assignment 1: Classification using Neural Network
#
# Now that you have developed and tested your model on the toy dataset set. It's time to get down and get dirty with a standard dataset such as cifar10. At this point, you will be using the provided training data to tune the hyper-parameters of your network such that it works with cifar10 for the task of multi-class classification.
#
# Important: Recall that now we have non-linear decision boundaries, thus we do not need to do one vs all classification. We learn a single non-linear decision boundary instead. Our non-linear boundaries (thanks to relu non-linearity) will take care of differentiating between all the classes
#
# TO SUBMIT: PDF of this notebook with all the required outputs and answers.

# %%
# Prepare Packages
import numpy as np
import matplotlib.pyplot as plt

from ece285.utils.data_processing import get_cifar10_data
from ece285.utils.evaluation import get_classification_accuracy


# %matplotlib inline
plt.rcParams["figure.figsize"] = (10.0, 8.0)  # set default size of plots

# For auto-reloading external modules
# See http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# Use a subset of CIFAR10 for the assignment
dataset = get_cifar10_data(
    subset_train=5000,
    subset_val=250,
    subset_test=500,
)

print(dataset.keys())
print("Training Set Data  Shape: ", dataset["x_train"].shape)
print("Training Set Label Shape: ", dataset["y_train"].shape)
print("Validation Set Data  Shape: ", dataset["x_val"].shape)
print("Validation Set Label Shape: ", dataset["y_val"].shape)
print("Test Set Data  Shape: ", dataset["x_test"].shape)
print("Test Set Label Shape: ", dataset["y_test"].shape)
# Out:
# dict_keys(['x_train', 'y_train', 'x_val', 'y_val', 'x_test', 'y_test'])
# Training Set Data  Shape:  (5000, 3072)
# Training Set Label Shape:  (5000,)
# Validation Set Data  Shape:  (250, 3072)
# Validation Set Label Shape:  (250,)
# Test Set Data  Shape:  (500, 3072)
# Test Set Label Shape:  (500,)

# %%
x_train = dataset["x_train"]
y_train = dataset["y_train"]
x_val = dataset["x_val"]
y_val = dataset["y_val"]
x_test = dataset["x_test"]
y_test = dataset["y_test"]

# %%
# Import more utilies and the layers you have implemented
from ece285.layers.sequential import Sequential
from ece285.layers.linear import Linear
from ece285.layers.relu import ReLU
from ece285.layers.softmax import Softmax
from ece285.layers.loss_func import CrossEntropyLoss
from ece285.utils.optimizer import SGD
from ece285.utils.dataset import DataLoader
from ece285.utils.trainer import Trainer

# %% [markdown]
# ## Visualize some examples from the dataset.

# %%
# We show a few examples of training images from each class.
classes = [
    "airplane",
    "automobile",
    "bird",
    "cat",
    "deer",
    "dog",
    "frog",
    "horse",
    "ship",
]
samples_per_class = 7


def visualize_data(dataset, classes, samples_per_class):
    num_classes = len(classes)
    for y, cls in enumerate(classes):
        idxs = np.flatnonzero(y_train == y)
        idxs = np.random.choice(idxs, samples_per_class, replace=False)
        for i, idx in enumerate(idxs):
            plt_idx = i * num_classes + y + 1
            plt.subplot(samples_per_class, num_classes, plt_idx)
            plt.imshow(dataset[idx])
            plt.axis("off")
            if i == 0:
                plt.title(cls)
    plt.show()


# Visualize the first 10 classes
visualize_data(
    x_train.reshape(5000, 3, 32, 32).transpose(0, 2, 3, 1),
    classes,
    samples_per_class,
)

# %% [markdown]
# ## Initialize the model

# %%
input_size = 3072
hidden_size = 100  # Hidden layer size (Hyper-parameter)
num_classes = 10  # Output

# For a default setting we use the same model we used for the toy dataset.
# This tells you the power of a 2 layered Neural Network. Recall the Universal Approximation Theorem.
# A 2 layer neural network with non-linearities can approximate any function, given large enough hidden layer
def init_model():
    # np.random.seed(0) # No need to fix the seed here
    l1 = Linear(input_size, hidden_size)
    l2 = Linear(hidden_size, num_classes)

    r1 = ReLU()
    softmax = Softmax()
    return Sequential([l1, r1, l2, softmax])

# %%
# Initialize the dataset with the dataloader class
dataset = DataLoader(x_train, y_train, x_val, y_val, x_test, y_test)
net = init_model()
optim = SGD(net, lr=0.01, weight_decay=0.01)
loss_func = CrossEntropyLoss()
epoch = 200  # (Hyper-parameter)
batch_size = 200  # (Reduce the batch size if your computer is unable to handle it)

# %%
# Initialize the trainer class by passing the above modules
trainer = Trainer(
    dataset, optim, net, loss_func, epoch, batch_size, validate_interval=3
)

# %%
# Call the trainer function we have already implemented for you. This trains the model for the given
# hyper-parameters. It follows the same procedure as in the last ipython notebook you used for the toy-dataset
train_error, validation_accuracy = trainer.train()
# Out:
# Epoch Average Loss:
# Epoch Average Loss: 1.890841
# Epoch Average Loss: 1.890527
# Validate Acc: 0.296
# Epoch Average Loss: 1.888152
# Epoch Average Loss: 1.885124
# Epoch Average Loss: 1.883150
# Validate Acc: 0.296
# Epoch Average Loss: 1.881458
# Epoch Average Loss: 1.880746
# Epoch Average Loss: 1.877914
# Validate Acc: 0.280
# Epoch Average Loss: 1.876807
# Epoch Average Loss: 1.875701
# Epoch Average Loss: 1.872758
# Validate Acc: 0.288
# Epoch Average Loss: 1.870608
# Epoch Average Loss: 1.868269
# Epoch Average Loss: 1.868111
# Validate Acc: 0.300
# Epoch Average Loss: 1.865533
# Epoch Average Loss: 1.863270
# Epoch Average Loss: 1.862648
# Validate Acc: 0.308
# Epoch Average Loss: 1.859527
# Epoch Average Loss: 1.858754
# Epoch Average Loss: 1.856118
# Validate Acc: 0.288
# Epoch Average Loss: 1.855006
# Epoch Average Loss: 1.850732
# Epoch Average Loss: 1.850613
# Validate Acc: 0.300
# Epoch Average Loss: 1.850400
# Epoch Average Loss: 1.846952
# Epoch Average Loss: 1.845170
# Validate Acc: 0.300
# Epoch Average Loss: 1.842338
# Epoch Average Loss: 1.840702
# Epoch Average Loss: 1.838141
# Validate Acc: 0.308
# Epoch Average Loss: 1.836697
# Epoch Average Loss: 1.834877
# Epoch Average Loss: 1.833791
# Validate Acc: 0.324
# Epoch Average Loss: 1.830885
# Epoch Average Loss: 1.828319
# Epoch Average Loss: 1.826795
# Validate Acc: 0.300
# Epoch Average Loss: 1.825285
# Epoch Average Loss: 1.823478
# Epoch Average Loss: 1.823674
# Validate Acc: 0.312
# Epoch Average Loss: 1.819519
# Epoch Average Loss: 1.819647
# Epoch Average Loss: 1.815862
# Validate Acc: 0.316
# Epoch Average Loss: 1.816469
# Epoch Average Loss: 1.812008
# Epoch Average Loss: 1.810306
# Validate Acc: 0.324
# Epoch Average Loss: 1.809301

# %% [markdown]
# ### Print the training and validation accuracies for the default hyper-parameters provided

# %%
from ece285.utils.evaluation import get_classification_accuracy

out_train = net.predict(x_train)
acc = get_classification_accuracy(out_train, y_train)
print("Training acc: ", acc)
out_val = net.predict(x_val)
acc = get_classification_accuracy(out_val, y_val)
print("Validation acc: ", acc)
# Out:
# Training acc:  0.3482
# Validation acc:  0.312

# %% [markdown]
# ### Debug the training
# With the default parameters we provided above, you should get a validation accuracy of around ~0.2 on the validation set. This isn't very good.
#
# One strategy for getting insight into what's wrong is to plot the training loss function and the validation accuracies during optimization.
#
# Another strategy is to visualize the weights that were learned in the first layer of the network. In most neural networks trained on visual data, the first layer weights typically show some visible structure when visualized.

# %%
# Plot the training loss function and validation accuracies
plt.subplot(2, 1, 1)
plt.plot(train_error)
plt.title("Training Loss History")
plt.xlabel("Iteration")
plt.ylabel("Loss")

plt.subplot(2, 1, 2)
# plt.plot(stats['train_acc_history'], label='train')
plt.plot(validation_accuracy, label="val")
plt.title("Classification accuracy history")
plt.xlabel("Epoch")
plt.ylabel("Classification accuracy")
plt.legend()
plt.show()

# %%
from ece285.utils.vis_utils import visualize_grid

# Credits: http://cs231n.stanford.edu/

# Visualize the weights of the network

def show_net_weights(net):
    W1 = net._modules[0].parameters[0]
    W1 = W1.reshape(3, 32, 32, -1).transpose(3, 1, 2, 0)
    plt.imshow(visualize_grid(W1, padding=3).astype("uint8"))
    plt.gca().axis("off")
    plt.show()


show_net_weights(net)

# %% [markdown]
# # Tune your hyperparameters (50%)
#
# **What's wrong?**. Looking at the visualizations above, we see that the loss is decreasing more or less linearly, which seems to suggest that the learning rate may be too low. Moreover, there is no gap between the training and validation accuracy, suggesting that the model we used has low capacity, and that we should increase its size. On the other hand, with a very large model we would expect to see more overfitting, which would manifest itself as a very large gap between the training and validation accuracy.
#
# **Tuning**. Tuning the hyperparameters and developing intuition for how they affect the final performance is a large part of using Neural Networks, so we want you to get a lot of practice. Below, you should experiment with different values of the various hyperparameters, including hidden layer size, learning rate, numer of training epochs, and regularization strength.
#
# **Approximate results**. You should be aim to achieve a classification accuracy of greater than 40% on the validation set. Our best network gets over 40% on the validation set.
#
# **Experiment**: You goal in this exercise is to get as good of a result on cifar10 as you can (40% could serve as a reference), with a fully-connected Neural Network.

# %% [markdown]
# #### Explain your hyperparameter tuning process below.
#
# #### Your Answer:
#     From the training error plot shown above, the model is underfitting, which fails to converge at the end. Therefore, I increase the learning rate and the size of hidden layers. At first, I use 200 batch size, 0.05 learning rate with 200 hidden layer size. This set is too ambitious that the model immediately overfits. I tune the learning rate between 0.01 to 0.05 while adjust the penalty of regularization from 0.01 to 0.05. The issues of overfitting can not be solved. I notice that the size of training set is only 5000 which is relatively small. I decide to use small learning rate and very light penalty with small batch size but more epochs. Based on that, my best set of hyperparameters are: batch size = 100, learning rate = 0.02, weight decay = 0.015, epoch size = 500, hidden layer size = 200.

# %%
# It should be noticed that the batch size is 100 for the below set of best hyperparameters 
best_net_hyperparams = [0.02, 0.015, 500, 200]  # store the best model into this

#################################################################################
# TODO: Tune hyperparameters using the validation set. Store your best trained  #
# model hyperparams in best_net.                                                #
#                                                                               #
# To help debug your network, it may help to use visualizations similar to the  #
# ones we used above; these visualizations will have significant qualitative    #
# differences from the ones we saw above for the poorly tuned network.          #
#                                                                               #
# You are now free to test different combinations of hyperparameters to build   #
# various models and test them according to the above plots and visualization   #


# TODO: Show the above plots and visualizations for the default params (already #
# done) and the best hyper-params you obtain. You only need to show this for 2  #
# sets of hyper-params.                                                         #
# You just need to store values for the hyperparameters in best_net_hyperparams #
# as a list in the order
# best_net_hyperparams = [lr, weight_decay, epoch, hidden_size]
#################################################################################
hidden_size = 200
net = init_model()
optim = SGD(net, lr=0.02, weight_decay=0.015)
loss_func = CrossEntropyLoss()
epoch = 500  # (Hyper-parameter)
batch_size = 100  # (Reduce the batch size if your computer is unable to handle it)

trainer = Trainer(
    dataset, optim, net, loss_func, epoch, batch_size, validate_interval=3
)

# %%
train_error, validation_accuracy = trainer.train()
# Out:
# Epoch Average Loss: 1.255498
# Validate Acc: 0.428
# Epoch Average Loss: 1.240920
# Epoch Average Loss: 1.244022
# Epoch Average Loss: 1.261821
# Validate Acc: 0.428
# Epoch Average Loss: 1.253514
# Epoch Average Loss: 1.249672
# Epoch Average Loss: 1.242210
# Validate Acc: 0.396
# Epoch Average Loss: 1.242711
# Epoch Average Loss: 1.235203
# Epoch Average Loss: 1.237592
# Validate Acc: 0.416
# Epoch Average Loss: 1.234881
# Epoch Average Loss: 1.247113
# Epoch Average Loss: 1.242054
# Validate Acc: 0.444
# Epoch Average Loss: 1.233184
# Epoch Average Loss: 1.266586
# Epoch Average Loss: 1.241542
# Validate Acc: 0.424
# Epoch Average Loss: 1.260203
# Epoch Average Loss: 1.237693
# Epoch Average Loss: 1.246898
# Validate Acc: 0.444
# Epoch Average Loss: 1.244834
# Epoch Average Loss: 1.238740
# Epoch Average Loss: 1.237323
# Validate Acc: 0.428
# Epoch Average Loss: 1.234003
# Epoch Average Loss: 1.236229
# Epoch Average Loss: 1.231372
# Validate Acc: 0.432
# Epoch Average Loss: 1.251067
# Epoch Average Loss: 1.239264
# Epoch Average Loss: 1.241549
# Validate Acc: 0.440
# Epoch Average Loss: 1.242431
# Epoch Average Loss: 1.243566
# Epoch Average Loss: 1.250979
# Validate Acc: 0.424
# Epoch Average Loss: 1.228450
# Epoch Average Loss: 1.243956
# Epoch Average Loss: 1.237532
# Validate Acc: 0.452
# Epoch Average Loss: 1.230731
# Epoch Average Loss: 1.231604
# Epoch Average Loss: 1.225099
# Validate Acc: 0.452
# Epoch Average Loss: 1.245392
# Epoch Average Loss: 1.241099
# Epoch Average Loss: 1.229784
# Validate Acc: 0.476
# Epoch Average Loss: 1.225932
# Epoch Average Loss: 1.240031
# Epoch Average Loss: 1.228094
# Validate Acc: 0.428
# Epoch Average Loss: 1.229592
# Epoch Average Loss: 1.250330
# Epoch Average Loss: 1.234888
# Validate Acc: 0.412
# Epoch Average Loss: 1.235646
# Epoch Average Loss: 1.244316
# Epoch Average Loss: 1.223610
# Validate Acc: 0.424
# Epoch Average Loss: 1.223364
# Epoch Average Loss: 1.227949
# Epoch Average Loss: 1.227031
# Validate Acc: 0.440
# Epoch Average Loss: 1.237726
# Epoch Average Loss: 1.238024
# Epoch Average Loss: 1.230756
# Validate Acc: 0.452
# Epoch Average Loss: 1.221691
# Epoch Average Loss: 1.228329
# Epoch Average Loss: 1.249511
# Validate Acc: 0.428
# Epoch Average Loss: 1.224689
# Epoch Average Loss: 1.226945
# Epoch Average Loss: 1.229827
# Validate Acc: 0.416
# Epoch Average Loss: 1.229915
# Epoch Average Loss: 1.178203
# Validate Acc: 0.440
# Epoch Average Loss: 1.165465
# Epoch Average Loss: 1.158419
# Epoch Average Loss: 1.170898
# Validate Acc: 0.456
# Epoch Average Loss: 1.159760
# Epoch Average Loss: 1.160541
# Epoch Average Loss: 1.159813
# Validate Acc: 0.464
# Epoch Average Loss: 1.168230
# Epoch Average Loss: 1.176070
# Epoch Average Loss: 1.173886
# Validate Acc: 0.468
# Epoch Average Loss: 1.171284
# Epoch Average Loss: 1.168613
# Epoch Average Loss: 1.161494
# Validate Acc: 0.412
# Epoch Average Loss: 1.167130
# Epoch Average Loss: 1.162223
# Epoch Average Loss: 1.166605
# Validate Acc: 0.436
# Epoch Average Loss: 1.168122
# Epoch Average Loss: 1.152673
# Epoch Average Loss: 1.156754
# Validate Acc: 0.476
# Epoch Average Loss: 1.165938
# Epoch Average Loss: 1.166241
# Epoch Average Loss: 1.172015
# Validate Acc: 0.444
# Epoch Average Loss: 1.152518
# Epoch Average Loss: 1.160259
# Epoch Average Loss: 1.165782
# Validate Acc: 0.464
# Epoch Average Loss: 1.158954
# Epoch Average Loss: 1.176548
# Epoch Average Loss: 1.156997
# Validate Acc: 0.424
# Epoch Average Loss: 1.172547
# Epoch Average Loss: 1.168150
# Epoch Average Loss: 1.155041
# Validate Acc: 0.380
# Epoch Average Loss: 1.170631
# Epoch Average Loss: 1.173041
# Epoch Average Loss: 1.163384
# Validate Acc: 0.440
# Epoch Average Loss: 1.177313
# Epoch Average Loss: 1.163006
# Epoch Average Loss: 1.173278
# Validate Acc: 0.464
# Epoch Average Loss: 1.156051
# Epoch Average Loss: 1.167685
# Epoch Average Loss: 1.163378
# Validate Acc: 0.440
# Epoch Average Loss: 1.165030
# Epoch Average Loss: 1.166513
# Epoch Average Loss: 1.154467
# Validate Acc: 0.444
# Epoch Average Loss: 1.172145
# Epoch Average Loss: 1.154104
# Epoch Average Loss: 1.170982
# Validate Acc: 0.416
# Epoch Average Loss: 1.160896
# Epoch Average Loss: 1.158096
# Epoch Average Loss: 1.160276
# Validate Acc: 0.432
# Epoch Average Loss: 1.178299
# Epoch Average Loss: 1.158829
# Epoch Average Loss: 1.168167
# Validate Acc: 0.464
# Epoch Average Loss: 1.159212
# Epoch Average Loss: 1.165283
# Epoch Average Loss: 1.151984
# Validate Acc: 0.440
# Epoch Average Loss: 1.151029
# Epoch Average Loss: 1.166187
# Epoch Average Loss: 1.155906
# Validate Acc: 0.452
# Epoch Average Loss: 1.168966
# Epoch Average Loss: 1.165253
# Epoch Average Loss: 1.171756
# Validate Acc: 0.480
# Epoch Average Loss: 1.173738

# %%
# TODO: Plot the training_error and validation_accuracy of the best network (5%)
plt.subplot(2, 1, 1)
plt.plot(train_error)
plt.title("Training Loss History")
plt.xlabel("Iteration")
plt.ylabel("Loss")

plt.subplot(2, 1, 2)
plt.plot(validation_accuracy, label="val")
plt.title("Classification accuracy history")
plt.xlabel("Epoch")
plt.ylabel("Classification accuracy")
plt.legend()
plt.show()

# %%
# TODO: visualize the weights of the best network (5%)
# Plot the training loss function and validation accuracies
show_net_weights(net)

# %% [markdown]
# # Run on the test set (30%)
# When you are done experimenting, you should evaluate your final trained network on the test set; you should get above 35%.

# %%
test_acc = (net.predict(x_test) == y_test).mean()
print("Test accuracy: ", test_acc)
# Out:
# Test accuracy:  0.404

# %% [markdown]
# #### Inline Question (10%)
#
# Now that you have trained a Neural Network classifier, you may find that your testing accuracy is much lower than the training accuracy. In what ways can we decrease this gap? Select all that apply.
#
# 1. Train on a larger dataset.
# 2. Add more hidden units.
# 3. Increase the regularization strength.
# 4. None of the above.
#
# #### Your Answer:
# 1 and 3
# #### Your Explanation:
# From the description, the classifier is overfitting. Therefore, increasing the size of dataset will allow the model to learn more new features. Besides, increasing the regularization strength is also a strategy to prevent the model from overfitting. Adding more hidden units is not able to help since the model is already overfitting.
